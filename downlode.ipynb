# %%
from pytubefix import YouTube

# Enter YouTube video URL
url = "https://youtube.com/shorts/IKrrc1SLLCg?si=8C2Q97AnMtvHVpOO"

# Create YouTube object
yt = YouTube(url)

# Get highest resolution stream
stream = yt.streams.get_highest_resolution()

# Download to current folder (can set path with download('path'))
stream.download('')

print("✅ Download complete!")
# Out:
# ✅ Download complete!

# %%
import ultralytics
from ultralytics import YOLO
model =YOLO(r"D:\GIT\GOAT-Findings\best.pt")
model.track(source='D:\GIT\GOAT-Findings\samples\goat.mp4',show=True)

# %%
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\Arunprakash Babu\AppData\Local\Temp\ipykernel_2732\1222076576.py:1: SyntaxWarning: invalid escape sequence '\G'
#   model.track(source='D:\GIT\GOAT-Findings\samples\goat.mp4',show=True)
# video 1/1 (frame 1/1602) D:\GIT\GOAT-Findings\samples\goat.mp4: 256x160 (no detections), 68.1ms
# ...
